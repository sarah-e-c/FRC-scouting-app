# %%
import pandas as pd
import numpy as np
import os

# %%
directory = 'teams_data'
 
team_paths = []


for filename in os.scandir(directory):
    if filename.is_file():
        team_paths.append(filename.path)

# %%
file_name = team_paths[0]
df = pd.read_csv(file_name)
df.head()
# Out:
#    Unnamed: 0 comp_level  event_key              key  match_number  \
# 0           0          f  2022va306   2022va306_f1m1             1
# 1           1         sf  2022va306  2022va306_sf1m1             1
# 2           2          f  2022va306   2022va306_f1m2             2
# 3           3         qm  2022va306    2022va306_qm2             2
# 4           4         sf  2022va306  2022va306_sf1m2             2
#
#    set_number winning_alliance team_alliance Teammate1 Teammate2  ...  \
# 0           1              red           red    frc384   frc7429  ...
# 1           1              red           red    frc384   frc7429  ...
# 2           1             blue           red    frc384   frc7429  ...
# 3           1              red           red    frc384   frc3939  ...
# 4           1              red           red    frc384   frc7429  ...
#
#   Opponent2 Opponent3 Taxied Hang TeamAutoLower TeamAutoUpper  \
# 0   frc6802   frc2028     No  Mid           1.0           3.0
# 1   frc3939   frc3359     No  Low           1.0           0.0
# 2   frc6802   frc2028     No  Mid           1.0           3.0
# 3   frc3359    frc122     No  Mid           0.0           1.0
# 4   frc3939   frc3359     No  Low           1.0           1.0
#
#    TeamTeleopLower  TeamTeleopUpper  TotalTeamPoints  WonGame
# 0              1.0              9.0             65.0      Yes
# 1              1.0             11.0             53.0      Yes
# 2              2.0              5.0             42.0       No
# 3              0.0              7.0             32.0      Yes
# 4              0.0              9.0             48.0      Yes
#
# [5 rows x 22 columns]

# %%
winrate_list = []
hang_score_list = []
team_auto_lower_list = []
team_auto_upper_list = []
team_tele_lower_list = []
team_tele_upper_list = []
total_team_points_list = []
highest_comp_level_list = []
team_name_list = []

print(file_name)

team_name_list.append(file_name.split('/')[1].split('data')[0])
print(team_name_list)

def get_winrate_highest_level(df):
    mapping = {'Yes': 1, 'Tie': 0.5, 'No': 0}
    winrate_list.append(df['WonGame'].map(mapping).mean())
    mapping_2 = {'None': 0, 'Low': 4, 'Mid': 8, 'High': 12, 'Traversal': 15}
    hang_score_list.append(df['Hang'].map(mapping_2).mean())
    team_auto_lower_list.append(df['TeamAutoLower'].mean())
    team_auto_upper_list.append(df['TeamAutoUpper'].mean())
    team_tele_lower_list.append(df['TeamTeleopLower'].mean())
    team_tele_upper_list.append(df['TeamTeleopUpper'].mean())
    mapping_3 = {'f': 5, 'sf': 3, 'qm': 0}
    highest_comp_level_list.append(df['comp_level'].map(mapping_3).max())
# Out:
# teams_data/frc384data.csv
# ['frc384']

# %%
get_winrate_highest_level(df)
print(winrate_list)
print(hang_score_list)
print(team_auto_lower_list)
print(team_auto_upper_list)
print(team_tele_lower_list)
print(team_tele_upper_list)
print(highest_comp_level_list)
# Out:
# [0.7413793103448276]
# [6.0344827586206895]
# [0.7586206896551724]
# [2.2413793103448274]
# [1.7241379310344827]
# [11.89655172413793]
# [5]

# %%
total_scores_df = pd.DataFrame({ 'TeamName': team_name_list,
                    'WinRate': winrate_list,
                    'TeamAutoLower': team_auto_lower_list,
                    'TeamAutoUpper': team_auto_upper_list,
                    'TeamTeleopLower': team_tele_lower_list,
                    'TeamTeleopUpper': team_tele_upper_list,
                    'HangScore': hang_score_list,
                    'HighestCompLevel': highest_comp_level_list
                    })
