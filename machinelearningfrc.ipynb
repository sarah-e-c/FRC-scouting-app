# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from xgboost import XGBRegressor
from xgboost import XGBClassifier
import match_selector as selector
import data_setup as setup
from model_wrapper import FRCModel

# %% [markdown]
# # Baseline model
# Note: there is a lot of data leakage in this cv because the team stats are based on the total stats that are calculated from these same matches. However, I will also predict the district champs to get a true sense of accuracy.

# %%
from model_wrapper import FRCModel
import data_setup as setup
model = FRCModel(late_weighting=1.5, mode='week_by_week')
all_data = pd.read_csv('all_matches_stats.csv')
about_all_matches = pd.read_json('all_matches_uncleaned.json')
X_train = all_data.iloc[selector.select_by_event_type(['District'], about_all_matches)]
y_train = X_train.pop('winning_alliance')

X_test = all_data.iloc[selector.select_by_event_type(['District Championship'], about_all_matches)]
y_test = X_test.pop('winning_alliance')

#XGBClassifier is picky :(
y_train = y_train.map(lambda x: x+1)
y_test = y_test.map(lambda x: x+1)
model.fit(included_weeks='all')
# Out:
# [0]
# condensing team averages...
# hello!
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# ...

# %%
X_train.drop(['Unnamed: 0', 'event_key'], axis=1, inplace=True)
X_test.drop(['Unnamed: 0', 'event_key'], axis=1, inplace=True)
# Out:
# /var/folders/65/53msqmfd7dl5_c575_p8112m0000gn/T/ipykernel_21274/4183940760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(['Unnamed: 0', 'event_key'], axis=1, inplace=True)
# /var/folders/65/53msqmfd7dl5_c575_p8112m0000gn/T/ipykernel_21274/4183940760.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(['Unnamed: 0', 'event_key'], axis=1, inplace=True)

# %% [markdown]
# With extra features: array([0.7826087 , 0.77941176, 0.79411765, 0.79411765, 0.86764706]) (mean: 80.3580)
# Without extra features: array([0.7826087 , 0.82352941, 0.76470588, 0.79411765, 0.80882353]) (mean: 79.4757)

# %%
from sklearn.metrics import accuracy_score
model = XGBClassifier()
model.fit(X_train,y_train)

accuracy_score(model.predict(X_test), y_test)
# Out:
# 0.7776523702031602

# %%
# #help(cross_val_predict)
# predictions = pd.Series(cross_val_predict(XGBClassifier(), X, y), name='Predictions')
# predictions_vs_actual = pd.DataFrame(predictions, y)

# %%
y.value_counts()
# Out:
# 2    7881
# 0    6465
# 1     181
# Name: winning_alliance, dtype: int64

# %%
pd.read_csv()
# Out:
#    winning_alliance  Predictions
# 0                 2            2
# 1                 2            2
# 2                 1            0
# 3                 2            2
# 4                 0            0

# %% [markdown]
# Lets load in the district champ data to test it for realzies D:

# %%
import requests

header = {'X-TBA-Auth-Key': 'j5psodzpSE2HyqjKqVQUfC35jmvDo8Cb0YFHZN6ky76Arm4rQ7H2xD370QSwEmsC'}

# %%
def team_lookup_averages(team_list, df_teams):
    team_winrate_list = []
    team_auto_lower_list = []
    team_auto_upper_list = []
    team_teleop_lower_list = []
    team_teleop_upper_list = []
    team_hang_score_list = []
    team_highest_comp_level_list = []
    
    for team in team_list:
        team_winrate_list.append(float(df_teams.loc[df_teams['TeamName'] == team]['WinRate']))
        team_auto_lower_list.append(float(df_teams.loc[df_teams['TeamName'] == team]['TeamAutoLower']))
        team_auto_upper_list.append(float(df_teams.loc[df_teams['TeamName'] == team]['TeamAutoUpper']))
        team_teleop_lower_list.append(float(df_teams.loc[df_teams['TeamName'] == team]['TeamTeleopLower']))
        team_teleop_upper_list.append(float(df_teams.loc[df_teams['TeamName'] == team]['TeamTeleopUpper']))
        team_hang_score_list.append(float(df_teams.loc[df_teams['TeamName'] == team]['HangScore']))
        team_highest_comp_level_list.append(float(df_teams.loc[df_teams['TeamName'] == team]['HighestCompLevel']))
    
    return pd.Series({'AvgWinrate': statistics.mean(team_winrate_list),
                        'HighestAvgWinrate': max(team_winrate_list),
                        'LowestAvgWinrate': min(team_winrate_list),

                        'AvgAutoLower': statistics.mean(team_auto_lower_list),
                        'HighestAutoLower': max(team_auto_lower_list),

                        'AvgAutoUpper': statistics.mean(team_auto_upper_list),
                        'HighestAutoUpper': max(team_auto_upper_list),

                        'AvgTeleopLower': statistics.mean(team_teleop_lower_list),
                        'HighestTelopLower': max(team_teleop_lower_list),

                        'AvgTelopUpper': statistics.mean(team_teleop_upper_list),
                        'HighestTelopUpper': max(team_teleop_upper_list),
                        'LowestTelopUpper': min(team_teleop_upper_list),


                        'AvgHangScore': statistics.mean(team_hang_score_list),

                        'AvgHighestCompLevel': statistics.mean(team_highest_comp_level_list),


                        })

def get_teams(df):
    red_teams_list = []
    blue_teams_list = []
    for i in range(df.shape[0]):
        red_teams_list.append(df.iloc[i]['alliances']['red']['team_keys'])
        blue_teams_list.append(df.iloc[i]['alliances']['blue']['team_keys'])
    return pd.DataFrame({'Red': red_teams_list, 'Blue': blue_teams_list})

def get_team_averages(team_list_df, df_team_info):
    series_list = []
    for i in range(team_list_df.shape[0]):
        team_info_red = team_lookup_averages(team_list_df.iloc[i]['Red'], df_team_info).rename('Red Averages')
        team_info_blue = team_lookup_averages(team_list_df.iloc[i]['Blue'], df_team_info).rename('Blue Averages')
        series_list.append(team_info_red - team_info_blue)
    
    return pd.DataFrame(series_list)

def clean_data(match_data, team_stats_df):
    teams_list = get_teams(match_data)
    winner_series = match_data['winning_alliance'].map({'red': 1, '': 0, 'blue': -1})
    return get_team_averages(teams_list, team_stats_df).join(winner_series)

team_stats_df = pd.read_csv('all_team_stats.csv')

source = requests.get(f'https://www.thebluealliance.com/api/v3/event/2022chcmp/matches', header).text
data = pd.read_json(source)
match_data = clean_data(data, team_stats_df)

# %%
from sklearn.metrics import accuracy_score
match_data
sns.heatmap(match_data.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRegressor
model_2 = XGBClassifier()
y_experiment = y.map(float)
model_2.fit(X,y_experiment)
X_test = match_data.copy()
y_test = X_test.pop('winning_alliance')

y_test = y_test.map(lambda x: x+1)


score = accuracy_score(y_test, model_2.predict(X_test))
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sarahcrowder/Desktop/codingStuff/machineLearningFRC/machinelearningfrc.ipynb Cell 19 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/sarahcrowder/Desktop/codingStuff/machineLearningFRC/machinelearningfrc.ipynb#ch0000015?line=3'>4</a> y_experiment = y.map(float)
#       <a href='vscode-notebook-cell:/Users/sarahcrowder/Desktop/codingStuff/machineLearningFRC/machinelearningfrc.ipynb#ch0000015?line=4'>5</a> model_2.fit(X,y_experiment)
# ----> <a href='vscode-notebook-cell:/Users/sarahcrowder/Desktop/codingStuff/machineLearningFRC/machinelearningfrc.ipynb#ch0000015?line=5'>6</a> X_test = match_data.copy()
#       <a href='vscode-notebook-cell:/Users/sarahcrowder/Desktop/codingStuff/machineLearningFRC/machinelearningfrc.ipynb#ch0000015?line=6'>7</a> y_test = X_test.pop('winning_alliance')
# ...

# %%
predictions = model_2.predict(X_test)
predictions_vs_actual_3 = pd.DataFrame(predictions, y_test).reset_index().rename({0:'prediction'}, axis=1)
predictions_vs_actual_3.head(30)

def confidence(num):
    if num > 2:
        return 'extremely confident red'
    elif num < 0:
        return 'extremely confident blue'
    elif num < 0.5:
        return 'very confident blue'
    elif num > 1.5:
        return 'very confident red'
    else:
        return 'toss up'


print(predictions_vs_actual_3)
# predictions_vs_actual_4 = predictions_vs_actual_3['prediction']
# Out:
#      winning_alliance  prediction
# 0                   2           2
# 1                   2           2
# 2                   2           2
# 3                   2           2
# 4                   0           2
# ..                ...         ...
# 133                 0           2
# 134                 2           2
# 135                 0           1
# 136                 2           1
# 137                 2           1
#
# [138 rows x 2 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/sarahcrowder/Desktop/codingStuff/machineLearningFRC/machinelearningfrc.ipynb Cell 17' in <cell line: 21>()
#      <a href='vscode-notebook-cell:/Users/sarahcrowder/Desktop/codingStuff/machineLearningFRC/machinelearningfrc.ipynb#ch0000020?line=17'>18</a> print(predictions_vs_actual_3)
# ...

# %%
score
# Out:
# 0.644927536231884

# %%
predictions_vs_actual_2 = pd.Series()
# Out:
# /var/folders/65/53msqmfd7dl5_c575_p8112m0000gn/T/ipykernel_86903/3776365494.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predictions_vs_actual_2 = pd.Series()

# %% [markdown]
# # Possible Extensions:
# * include max winrate and min winrate player's stats as features
# * Weigh the later comps more in team stats (a bit of an issue for post training, but would be really useful as a tool, especially for things like hang score)
# * Use a regressor instead
